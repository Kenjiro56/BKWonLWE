# %%
from sage.modules.free_module_integer import IntegerLattice # type: ignore
import random
import itertools
from sortedcontainers import SortedList, SortedDict # type: ignore
from sage.rings.finite_rings.hom_finite_field import FiniteFieldHomomorphism_generic # type: ignore


#####################################################
#### Auxiliary Tools for Choosing Instance Parameters
#####################################################

def investigate(k, q):
    """
    give various info about factorization of q^k-1（因数分解に関しての情報を出力する関数）

    Parameters
    ----------
    k : int
        変数 
    q : int
        素数
    """
    for d in divisors(k): # type: ignore
        print("factor q^" + k/d + "-1: ", factor( q^(k/d)-1 )) # type: ignore
    
def find_primes(lowbound, upbound, power_of_two ):
    """
    list primes in a range with a certain power of two in base field（特定の2冪の範囲内の素数のリストを作成する関数）

    Parameters
    --------
    lowbound : int
        下界
    upbound : int
        上界
    power_of_two : int
        2冪

    Returns
    --------
    primes : list
        lowbound以上、upbound以下でpower_of_twoと違いに素な値のリスト
    """
    return [ _ for _ in primes(lowbound, upbound) if Mod(_,power_of_two)==1 ] # type: ignore

def emb_degree(n, q):
    """
    compute embedding degree（埋め込み次数の計算）

    Parameters
    ----------
    n : int
        n = dim, i.e. 2n roots of unity
    q : int
        q=prime

    Returns
    ----------
    emb_degree : int
        埋め込み次数
    """
    emb_degree_flag = 0
    emb_degree = 1
    while emb_degree_flag == 0:
        if Mod(q^emb_degree-1,2*n) != 0:
            emb_degree += 1
        else:
            emb_degree_flag = 1
    return emb_degree
    

################################################    
#### Rq = R/qR class
################################################
#### this class generates the ring Rq and its tower of subrings
#### this class guarantees that the generator of a subring is the square of the generator of the next larger ring in the tower
#### it allows for tracing into the subfield and for embedding subring back into big ring
################################################

class Rq:
    
    def __init__(self, dim, prime):  
        
        ## Notes:
        ## dim -> 2*dim th roots appear, 
        ## dim = dimension of this ring over Fq, must be power of two
        ## q = prime; modpoly = polynomial
    
        ### Dimension of big ring, must be power of two
        self.n = dim
        
        ### log base 2 of dimension
        self.logn = ZZ(log(self.n,2)) # exponent such that dimension = 2^exponent
        
        ### prime field we work over
        self.q = prime
        
        ### Generate the underlying prime field 
        self.F = GF(self.q)
        
        ### Generate the tower of rings
        ###############################
        
        ### rings stores a list of [ring,generator] in increasing order
        ### rings[0] is the finite field with generator -1
        self.rings = [ [self.F, self.F(-1)] ]
        
        ### the largest ring is index self.logn
        for i in range(1,self.logn+1):
            lastring = self.rings[i-1]
            # S.<x> = PolynomialRing(lastring[0], 'x')
            S.<x> = PolynomialRing(lastring[0], 'x')
            zetaname = 'z' + str(i); # z0 = -1, z1 = i, etc.
            R = S.quotient( x^2 - lastring[1], zetaname ) # take square root of last generator
            self.rings.append( [R, R.gen()] )
            
        ### bigring is the largest ring, used most often
        self.bigring = self.rings[self.logn][0]
        
        ### Report on the ring created
        # print("Ring: ", self.bigring)
        # print("Size of ring in bits: ", log( self.q^self.n, 2 ).n())
        
        ### Store ring generator (zeta) and report
        self.r = self.rings[self.logn][1]
        # print("Ring generator (2n-th root): ", self.r)

        ### store powers of r for later use
        r_pows = [ self.r^i for i in range(self.n) ]
        


    def iterator(self, i):  # iterator for the subring of index 2^i
        ring = self.rings[self.logn-i][0]
        gen = self.rings[self.logn-i][1]
        repeatrange = self.n/(2^i)
        gen_pows = [ gen^_ for _ in range(repeatrange) ]
        print(gen_pows)
        for tuple in itertools.product(self.F,repeat=repeatrange):
            elt = ring(0)
            for i in range(repeatrange):
                elt += gen_pows[i]*tuple[i]
            yield elt
            
    def subring(self, i ):  # return index 2^i subring
        return self.rings[self.logn-1-i][0]
        
    def subgen(self, i ):  # return generator of index 2^i subring
        return self.subrings[self.logn-1-i][1]
        
    def coefficient_list_onestep(self, elt ):  # return the coefficient list in terms of subring of index 2
        return elt.list()
        
    def coefficient_list(self, elt):  # return the coefficient list in terms of powers of zeta (self.r)
        if elt.parent() == self.rings[0][0]:
            return elt
        else:
            returnlist = []
            coeffs_lower = self.coefficient_list_onestep(elt);
            if coeffs_lower[0].parent() == self.rings[0][0]:
                return coeffs_lower
            list1 = self.coefficient_list(coeffs_lower[0])
            list2 = self.coefficient_list(coeffs_lower[1])
            for i in range(len(list1)):
                returnlist.append(list1[i])
                returnlist.append(list2[i])
            return returnlist            
        
    def trace_red_1(self, ringindex, elt):   # return trace to index 2 subring
        return self.rings[ringindex][0](elt).list()[0]
            
    def trace_red(self, elt, i ):   # return the trace to the index 2^i subring (i=1 is subfield of index 2)
        myelt = elt
        for j in range(i):
            myelt = self.trace_red_1(self.logn - j, myelt)
        return myelt
        
        
################################################
#### Two-Power Cyclotomic Ring-LWE Class
################################################
#### this class generates a Ring-LWE instance
#### this means 
####       1) ring Rq object
####       2) error generator, check if something is an error
####       3) fake (i.e. uniform) sample generator
#### it doesn't include or know about a secret (that's what an oracle class is for)
################################################

class RingLWE:
    
    def __init__(self, dim, prime, error_sigma ): # dim must be a power of two, indicating x^dim+1 (2dim-th roots)

        ### Set up and report basic parameters
        self.n = dim
        self.m = 2*dim
        self.q = prime
        self.sigma = error_sigma
        # print("Initializing a Ring-LWE with dimension ", dim, " (meaning ", 2*dim, "-th roots), prime ", prime, " and error width ", error_sigma)
        
        ### Compute embedding degree and report
        self.k = emb_degree( self.n, self.q )
        # print("embedding degree self.k: ", self.k)
        
        ### Create the ring Rq
        self.Rq = Rq(self.n, self.q)
        self.r = self.Rq.bigring.gen()
        
        # print("Primitive 2n-th root of unity r = ", self.r)
        # print("Primitive n-th root of unity t = r^2 = ", self.r^2)
            
        ### save powers of primitive root
        self.r_pows = [ self.r^_ for _ in range(self.n) ]
        
        ### compute error coefficient range and save
        self.error_coeffs_range = range(-self.sigma,self.sigma+1)

    def get_error(self):  # return a random error
        coeffs = [ random.choice(self.error_coeffs_range) for _ in range(self.n) ] # for m-th roots, choose coefficients
        eg = 0
        for jj in range(len(coeffs)):
            eg += coeffs[jj]*self.r_pows[jj]
        return eg
    
    def get_fake_sample(self):  # return a uniform (non-valid) sample
        aa = self.Rq.bigring.random_element()
        bb = self.Rq.bigring.random_element()
        return [aa,bb]
        
    def trace_red(self, elt, i ):   # return the trace to the index 2^i subfield (i=1 is subfield of index 2)
        return self.Rq.trace_red(elt, i)
        
    def coset_rep(self, elt ):   # return a representative of the mult. coset of the index 2 subfield
        my_trace = self.trace_red(self.Rq(elt))
        if my_trace == 0:
            return self.r
        else:
            return self.Rq(elt)/my_trace
    
    def is_error(self, elt):  # check if elt in Rq is an error
        eltlist = self.Rq.coefficient_list(elt)
        error_flag = True
        for i in range( self.k ):
            if eltlist[i] not in self.error_coeffs_range:
                error_flag = False
                break
        return error_flag
        
    def secretanought_recreation(self, downdim, anought, clist):  # given a list of c's, uses Main Theorem to reconstruct secret
        anought_trace = self.trace_red(anought,downdim)
        zcoeffs = [0 for _ in range(self.n)]
        for j in range( 2^downdim ):
            vcoeffs = self.Rq.coefficient_list(self.Rq.bigring(clist[j]*anought_trace))
            # print("v coeffs:", vcoeffs)
            for i in range( self.n/(2^downdim) ):
                zcoeffs[i*(2^downdim) - j] = vcoeffs[i*2^downdim]
                if i*(2^downdim) - j < 0 :
                    zcoeffs[i*(2^downdim)-j] = -vcoeffs[i*2^downdim]
        # print("z coeffs:", zcoeffs)
        print(self.r_pows)
        z = 0
        for jj in range(len(zcoeffs)):
            z += zcoeffs[jj]*self.r_pows[jj]
        # print("z: ", z)
        return z
        
        
        
################################################
#### Oracle class
################################################    
#### The Oracle is the secret keeper
#### It is created on an rlwe instance and gives out valid samples
#### This has a cheat_sample function where you can generate samples with desired 'a' value
################################################

class Oracle:
    
    def __init__(self, rlwe ): # using some Ring-LWE instance, create an oracle that keeps a secret and offers samples
               
        ### Set the secret
        self.secret = rlwe.Rq.bigring.random_element()
        self.rlwe = rlwe
        
    def get_valid_sample(self):  # return a valid sample, random a
        aa = self.rlwe.Rq.bigring.random_element()
        bb = aa*self.secret + self.rlwe.get_error()
        return [aa,bb]
    
    def create_samps(self, numsamps): # create a list of valid samples of requested length
        samples = [] 
        for i in range(numsamps):   # first numsamps-1 elements of avals are the auxiliary samples
            mysamp = self.get_valid_sample()
            samples.append(mysamp)
        return samples
        
    def cheat_sample(self, aa):  # create a sample with given aa value (cheating!)
        bb = aa*self.secret + self.rlwe.get_error()
        return [aa,bb]
        

        
############################################
#### Simple exhaustive search
############################################
#### Given a Ring-LWE instance and a sample list,
#### perform exhaustive search to find secret
############################################

class Exhaust:
    
    def __init__(self, rlwe, samplist ):  # using the rlwe instance
        
        #### set up 
        self.rlwe = rlwe
        self.samps_list = samplist
         
    def find_c(self):  # look for possible secret "c", given samps, a list of reduced samples
        poss_c = []
        for c in self.rlwe.Rq.iterator(0):
            possible_flag = True
            for samp in self.samps_list:
                putative = samp[1] - samp[0]*c
                if not self.rlwe.is_error(putative):
                    possible_flag = False
                    break
            if possible_flag:
                poss_c.append(c)
                # print("possible c:", c)
        return poss_c
        
    def find_secret(self):   # try to find a possible secret and report on outcome
        poss_c = self.find_c()
        if len(poss_c) > 1:
            print("please try more samples")
            return False
        elif len(poss_c) == 0:
            print("error, no solutions")
            return False
        else:
            # print("guessed secret:", poss_c[0])
            return poss_c[0]
    
############################################
#### Reduction Theorem
############################################
#### This takes in a ring-lwe object and sample list from one (specified) multiplicative coset
#### It gives out sample lists for an RLWE of reduced dimension
############################################

class Reduction:
    
    def __init__(self, rlwe, samplist, downdim, anought ):
        
        #### set up 
        self.rlwe = rlwe
        self.samplist = samplist
        self.downdim = downdim # downdim is the exponent (number of 2s) we move down; 1 -> index 2 subfield
        self.anought = anought
        
        #### Create the reduced sample lists
        self.samplists = [0 for _ in range(2^self.downdim)]
        for i in range(2^self.downdim):
            self.create_reduced_samplist(i)
        
    def create_reduced_samplist(self, j ):
        
        #### Create the trace-reduced samples
        newsamplist = []
        for samp in self.samplist:
            trace = self.rlwe.Rq.trace_red(samp[0], self.downdim)
            ring = self.rlwe.Rq.rings[self.rlwe.Rq.logn - self.downdim][0]
            newa = ring(self.rlwe.Rq.trace_red(samp[0], self.downdim))
            newb = ring(self.rlwe.Rq.trace_red(samp[1]*self.rlwe.r_pows[j], self.downdim))
            newsamplist.append([newa,newb])
            
        self.samplists[j] = newsamplist

# %%
### q = prime, n = 2 power dimension
n = 16
q = 13

name = 'change_dimenstion'
file_name = './outputs/' + name + '.csv'
try_count = 100

f = open(file_name,'w',encoding='UTF-8')
f.write('n,accuracy\n')

while(n <= 2**10):
    print("{}次元始まった".format(n))
    accuracy = 0.0
    correct_num = 0

    for t in range(try_count):
        ### Choose how many dimensions to trace down (to index 2^downdim subring)
        downdim = 2
        ### Build RingLWE instance object, and oracle with random secret
        myRLWE = RingLWE(n,q,1)
        myOracle = Oracle(myRLWE)
        ### Choose a particular multiplicative coset
        anought = myRLWE.Rq.bigring.random_element(); anought
        ### Generate a sample list from the oracle, which cheats and uses a's drawn from the specified multiplicative coset
        samplist = []
        for i in range(200):
            samplist.append(myOracle.cheat_sample(anought*myRLWE.Rq.rings[downdim][0].random_element()))
        ### Produce an instance of the Reduction Theorem object
        myRed = Reduction( myRLWE, samplist, downdim, anought)
        ### Produce an instance of the smaller Ring-LWE object
        smallRLWE = RingLWE(ZZ(myRLWE.n/2^downdim), myRLWE.q, 2)
        ### Run exhaustive search on the smaller Ring-LWE instances and collect results
        clist = []
        for i in range( 2^downdim ):
            ex = Exhaust( smallRLWE, myRed.samplists[i] )
            clist.append(ex.find_secret())
        ### Do the linear algebra to recombine the secret*anought
        guessedSecret = myRLWE.secretanought_recreation(downdim, anought, clist)
        realSecret = myOracle.secret*anought
        # print("\n\n")
        # print("*****************************************************************************************************************************")
        # print("My guessed secret*anought\n", guessedSecret)
        # print("My real secret*anought\n", realSecret)
        if guessedSecret == realSecret:
            correct_num = correct_num + 1
        print("{}回終わった".format(t))
    print("breakした")

    accuracy = correct_num/try_count
    print('n = ',n, 'accuracy = ',accuracy)
    f.write("{}, {}\n".format(n, accuracy))
    f.writelines
    n = n * 2

f.close()
# Out:
# 16次元始まった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 0回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 1回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 2回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 3回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 4回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 5回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 6回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 7回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 8回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 9回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 10回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 11回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 12回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 13回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 14回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 15回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 16回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 17回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 18回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 19回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 20回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 21回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 22回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 23回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 24回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 25回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 26回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 27回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 28回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 29回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 30回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 31回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 32回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 33回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 34回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 35回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 36回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 37回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 38回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 39回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 40回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 41回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 42回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 43回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 44回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 45回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 46回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 47回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 48回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 49回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 50回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 51回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 52回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 53回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 54回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 55回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 56回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 57回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 58回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 59回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 60回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 61回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 62回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 63回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 64回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 65回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 66回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 67回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 68回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 69回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 70回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 71回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 72回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 73回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 74回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 75回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 76回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 77回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 78回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 79回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 80回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 81回終わった
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 82回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 83回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 84回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 85回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 86回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 87回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 88回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 89回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 90回終わった
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z2, z1, z1*z2]
# error, no solutions
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 91回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 92回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 93回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 94回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 95回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 96回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 97回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 98回終わった
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z2, z1, z1*z2]
# [1, z4, z3, z3*z4, z2, z2*z4, z2*z3, z2*z3*z4, z1, z1*z4, z1*z3, z1*z3*z4, z1*z2, z1*z2*z4, z1*z2*z3, z1*z2*z3*z4]
# 99回終わった
# breakした
# n =  16 accuracy =  49/50
# 32次元始まった
# [1, z3, z2, z2*z3, z1, z1*z3, z1*z2, z1*z2*z3]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 37
#      35 for i in range( Integer(2)**downdim ):
#      36     ex = Exhaust( smallRLWE, myRed.samplists[i] )
# ---> 37     clist.append(ex.find_secret())
#      38 ### Do the linear algebra to recombine the secret*anought
#      39 guessedSecret = myRLWE.secretanought_recreation(downdim, anought, clist)
#
# Cell In[28], line 333, in Exhaust.find_secret(self)
#     332 def find_secret(self):   # try to find a possible secret and report on outcome
# --> 333     poss_c = self.find_c()
#     334     if len(poss_c) > Integer(1):
#     335         print("please try more samples")
#
# Cell In[28], line 323, in Exhaust.find_c(self)
#     321 possible_flag = True
#     322 for samp in self.samps_list:
# --> 323     putative = samp[Integer(1)] - samp[Integer(0)]*c
#     324     if not self.rlwe.is_error(putative):
#     325         possible_flag = False
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:1504, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:20029)()
#    1502 cdef int cl = classify_elements(left, right)
#    1503 if HAVE_SAME_PARENT(cl):
# -> 1504     return (<Element>left)._mul_(right)
#    1505 if BOTH_ARE_ELEMENT(cl):
#    1506     return coercion_model.bin_op(left, right, mul)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:2638, in sage.structure.element.RingElement._mul_ (build/cythonized/sage/structure/element.c:27862)()
#    2636
#    2637 cdef class RingElement(ModuleElement):
# -> 2638     cpdef _mul_(self, other) noexcept:
#    2639         """
#    2640         Abstract multiplication method
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_quotient_ring_element.py:249, in PolynomialQuotientRingElement._mul_(self, right)
#     238 """
#     239 Return the product of two polynomial ring quotient elements.
#     240
#    (...)
#     246     2*a^2 - 4*a - 6
#     247 """
#     248 R = self.parent()
# --> 249 prod = self._polynomial * right._polynomial
#     250 return self.__class__(R, prod, check=False)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:1504, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:20029)()
#    1502 cdef int cl = classify_elements(left, right)
#    1503 if HAVE_SAME_PARENT(cl):
# -> 1504     return (<Element>left)._mul_(right)
#    1505 if BOTH_ARE_ELEMENT(cl):
#    1506     return coercion_model.bin_op(left, right, mul)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_element.pyx:1839, in sage.rings.polynomial.polynomial_element.Polynomial._mul_ (build/cythonized/sage/rings/polynomial/polynomial_element.c:29060)()
#    1837
#    1838         elif self._parent.is_exact():
# -> 1839             return self._mul_karatsuba(right)
#    1840         else:
#    1841             return self._mul_generic(right)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_element.pyx:3721, in sage.rings.polynomial.polynomial_element.Polynomial._mul_karatsuba (build/cythonized/sage/rings/polynomial/polynomial_element.c:45614)()
#    3719     K_threshold = self._parent._Karatsuba_threshold
#    3720 if n <= K_threshold or m <= K_threshold:
# -> 3721     return self._new_generic(do_schoolbook_product(f, g, -1))
#    3722 if n == m:
#    3723     return self._new_generic(do_karatsuba(f,g, K_threshold, 0, 0, n))
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_element.pyx:11767, in sage.rings.polynomial.polynomial_element.do_schoolbook_product (build/cythonized/sage/rings/polynomial/polynomial_element.c:115151)()
#   11765     sum = x[start] * y[k-start]
#   11766     for i from start < i <= end:
# > 11767         sum = sum + x[i] * y[k-i]
#   11768     coeffs[k] = sum
#   11769 return coeffs
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:1218, in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:18786)()
#    1216 cdef int cl = classify_elements(left, right)
#    1217 if HAVE_SAME_PARENT(cl):
# -> 1218     return (<Element>left)._add_(right)
#    1219 # Left and right are Sage elements => use coercion model
#    1220 if BOTH_ARE_ELEMENT(cl):
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:2370, in sage.structure.element.ModuleElement._add_ (build/cythonized/sage/structure/element.c:23596)()
#    2368 Generic element of a module.
#    2369 """
# -> 2370 cpdef _add_(self, other) noexcept:
#    2371     """
#    2372     Abstract addition method
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_quotient_ring_element.py:282, in PolynomialQuotientRingElement._add_(self, right)
#     268 def _add_(self, right):
#     269     """
#     270     Return the sum of two polynomial ring quotient elements.
#     271
#    (...)
#     279         a + 1
#     280     """
#     281     return self.__class__(self.parent(),
# --> 282                                          self._polynomial + right._polynomial, check=False)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:1218, in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:18786)()
#    1216 cdef int cl = classify_elements(left, right)
#    1217 if HAVE_SAME_PARENT(cl):
# -> 1218     return (<Element>left)._add_(right)
#    1219 # Left and right are Sage elements => use coercion model
#    1220 if BOTH_ARE_ELEMENT(cl):
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_element.pyx:12286, in sage.rings.polynomial.polynomial_element.Polynomial_generic_dense._add_ (build/cythonized/sage/rings/polynomial/polynomial_element.c:120882)()
#   12284 else:
#   12285     min = len(x)
# > 12286 cdef list low = [x[i] + y[i] for i from 0 <= i < min]
#   12287 if len(x) == len(y):
#   12288     res = self._new_c(low, self._parent)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:1218, in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:18786)()
#    1216 cdef int cl = classify_elements(left, right)
#    1217 if HAVE_SAME_PARENT(cl):
# -> 1218     return (<Element>left)._add_(right)
#    1219 # Left and right are Sage elements => use coercion model
#    1220 if BOTH_ARE_ELEMENT(cl):
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/structure/element.pyx:2370, in sage.structure.element.ModuleElement._add_ (build/cythonized/sage/structure/element.c:23596)()
#    2368 Generic element of a module.
#    2369 """
# -> 2370 cpdef _add_(self, other) noexcept:
#    2371     """
#    2372     Abstract addition method
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_quotient_ring_element.py:281, in PolynomialQuotientRingElement._add_(self, right)
#     268 def _add_(self, right):
#     269     """
#     270     Return the sum of two polynomial ring quotient elements.
#     271
#    (...)
#     279         a + 1
#     280     """
# --> 281     return self.__class__(self.parent(),
#     282                                          self._polynomial + right._polynomial, check=False)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/rings/polynomial/polynomial_quotient_ring_element.py:109, in PolynomialQuotientRingElement.__init__(self, parent, polynomial, check)
#      93 class PolynomialQuotientRingElement(polynomial_singular_interface.Polynomial_singular_repr, CommutativeRingElement):
#      94     """
#      95     Element of a quotient of a polynomial ring.
#      96
#    (...)
#     107
#     108     """
# --> 109     def __init__(self, parent, polynomial, check=True):
#     110         """
#     111         Create an element of the quotient of a polynomial ring.
#     112
#    (...)
#     122            (mod the modulus).
#     123         """
#     124         from sage.rings.polynomial.polynomial_quotient_ring import PolynomialQuotientRing_generic
#
# File src/cysignals/signals.pyx:341, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
